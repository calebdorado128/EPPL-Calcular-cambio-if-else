# %% [markdown]
# <a href="https://colab.research.google.com/github/calebdorado128/EPPL-Calcular-cambio-if-else/blob/main/El_profe_Act_12_Cambio_Caleb_Dorado_0039.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Caleb Dorado, NL = 14, Fecha = 26/Mar/2026
# ### Calculando cambio usando if else
# ### Mirar diagrama de flujo
# ![](https://raw.githubusercontent.com/calebdorado128/EPPL-Calcular-cambio-if-else/refs/heads/main/Cambio.JPG)
#
# ### Las Variables
# 1. CP --> Costo de producto
# 2. CD --> Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $Cambio = CD - CP$
# ---
#
# ## Diagrama de flujo en LucidChart
# ![](https://raw.githubusercontent.com/calebdorado128/EPPL-Calcular-cambio-if-else/refs/heads/main/DF%20if%20else%20cmbio%202.jpeg)

# %%
# Para cuando es verdader0o
# Calculando el cambio usando if else
# Datos de entrada: CD, CP
# Mostrar Cambio si es falso
# Si es verdadero mostrar "No alcanza"
CP = int(input("Ingrese el costo del producto: "))
CD = int(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio = CD - CP
    print("El cambio es: ", Cambio)

print("Fin del programa")
print("Programa realizado por Caleb Dorado 0039")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 600
# El cambio es:  100
# Fin del programa
# Programa realizado por Caleb Dorado 0039

# %%
# Para cuando es verdader0o
# Calculando el cambio usando if else
# Datos de entrada: CD, CP
# Mostrar Cambio si es falso
# Si es verdadero mostrar "No alcanza"
CP = int(input("Ingrese el costo del producto: "))
CD = int(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
    Cambio = CD - CP
    print("El cambio es: ", Cambio)

print("Fin del programa")
print("Programa realizado por Caleb Dorado 0039")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# Fin del programa
# Programa realizado por Caleb Dorado 0039

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# ![](https://raw.githubusercontent.com/calebdorado128/EPPL-Calcular-cambio-if-else/refs/heads/main/TlDraw%20codigo%20diagrama%20de%20flujo%20act%2012.png)
